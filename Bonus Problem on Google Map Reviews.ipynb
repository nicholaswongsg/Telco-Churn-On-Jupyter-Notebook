# %%
# Problem 1
# Import the “train.csv” data you downloaded (either from NTU Learn or Kaggle) in Jupyter Notebook

import numpy as np
import pandas as pd

import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %%
# Problem 2
# Import the Wikipedia page in Jupyter Notebook (check M1 DataAcquisition.ipynb for hints about this).

html_data = pd.read_html('https://www.google.com/search?q=singtel&rlz=1C5CHFA_enSG963SG963&sxsrf=APq-WBsPJ7owCdgWcYBixXYU2tnwtWsNfg:1647592134332&ei=vkI0YsrgO_baz7sP1bW9aA&ved=2ahUKEwi27pr_ns_2AhUi73MBHdIwB3cQvS56BAguEEU&uact=5&oq=singtel&gs_lcp=&sclient=gws-wiz&tbs=lf:1,lf_ui:4&tbm=lcl&rflfq=1&num=10&rldimm=6094993154110801552&lqi=CgdzaW5ndGVsIgOIAQFItI_v4uWAgIAIWhMQABgAIgdzaW5ndGVsKgQIAhAAkgEjdGVsZWNvbW11bmljYXRpb25zX3NlcnZpY2VfcHJvdmlkZXKqAQ8QASoLIgdzaW5ndGVsKAA&rlst=f#lrd=0x31da1958a5f43d55:0x5495c3fb23364690,1,,,&rlfi=hd:;si:6094993154110801552,l,CgdzaW5ndGVsIgOIAQFItI_v4uWAgIAIWhMQABgAIgdzaW5ndGVsKgQIAhAAkgEjdGVsZWNvbW11bmljYXRpb25zX3NlcnZpY2VfcHJvdmlkZXKqAQ8QASoLIgdzaW5ndGVsKAA;mv:[[1.3141672,103.8587244],[1.2605866,103.8154325]];tbs:lrf:!1m4!1u3!2m2!3m1!1e1!2m1!1e3!2m4!1e17!4m2!17m1!1e2!3sIAE,lf:1,lf_ui:4')
html_data
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /var/folders/f1/b9jtl_x97kd8y5n9h1btlbj40000gn/T/ipykernel_3930/1993789586.py in <module>
#       2 # Import the Wikipedia page in Jupyter Notebook (check M1 DataAcquisition.ipynb for hints about this).
#       3
# ...
